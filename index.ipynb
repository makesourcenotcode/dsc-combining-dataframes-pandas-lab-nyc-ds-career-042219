# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
#
#
# ## Getting Started
#
# You'll start with a quick section to gain practice with concatenating datasets using `pd.concat()`.
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df = pd.concat([df1,df2,df3])

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting Join Conditions With Concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = pd.concat([df1,df4],join='inner',axis=1)
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Loading In Data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame.  You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index('card_id')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-bab907a598d0> in <module>()
# ----> 1 cards_df.set_index('card_id')
#
# NameError: name 'cards_df' is not defined

# %%
dust_df.set_index('card_id')
# Out:
#                       action  cost
# card_id
# BRM_010t2    CRAFTING_NORMAL    40
# BRM_010t2    CRAFTING_GOLDEN   400
# BRM_010t2  DISENCHANT_NORMAL     5
# BRM_010t2  DISENCHANT_GOLDEN    50
# AT_132       CRAFTING_NORMAL  1600
# AT_132       CRAFTING_GOLDEN  3200
# AT_132     DISENCHANT_NORMAL   400
# AT_132     DISENCHANT_GOLDEN  1600
# OG_141       CRAFTING_NORMAL    40
# OG_141       CRAFTING_GOLDEN   400
# OG_141     DISENCHANT_NORMAL     5
# OG_141     DISENCHANT_GOLDEN    50
# AT_131       CRAFTING_NORMAL  1600
# AT_131       CRAFTING_GOLDEN  3200
# AT_131     DISENCHANT_NORMAL   400
# AT_131     DISENCHANT_GOLDEN  1600
# EX1_583      CRAFTING_NORMAL    40
# EX1_583      CRAFTING_GOLDEN   400
# EX1_583    DISENCHANT_NORMAL     5
# EX1_583    DISENCHANT_GOLDEN    50
# CFM_095      CRAFTING_NORMAL   400
# CFM_095      CRAFTING_GOLDEN  1600
# CFM_095    DISENCHANT_NORMAL   100
# CFM_095    DISENCHANT_GOLDEN   400
# BRM_018      CRAFTING_NORMAL   100
# BRM_018      CRAFTING_GOLDEN   800
# BRM_018    DISENCHANT_NORMAL    20
# BRM_018    DISENCHANT_GOLDEN   100
# OG_027       CRAFTING_NORMAL   100
# OG_027       CRAFTING_GOLDEN   800
# ...                      ...   ...
# tt_010a    DISENCHANT_NORMAL   100
# tt_010a    DISENCHANT_GOLDEN   400
# EX1_559      CRAFTING_NORMAL  1600
# EX1_559      CRAFTING_GOLDEN  3200
# EX1_559    DISENCHANT_NORMAL   400
# EX1_559    DISENCHANT_GOLDEN  1600
# EX1_624      CRAFTING_NORMAL   100
# EX1_624      CRAFTING_GOLDEN   800
# EX1_624    DISENCHANT_NORMAL    20
# EX1_624    DISENCHANT_GOLDEN   100
# OG_044a      CRAFTING_NORMAL    40
# OG_044a      CRAFTING_GOLDEN   400
# OG_044a    DISENCHANT_NORMAL     5
# OG_044a    DISENCHANT_GOLDEN    50
# AT_044       CRAFTING_NORMAL   400
# AT_044       CRAFTING_GOLDEN  1600
# AT_044     DISENCHANT_NORMAL   100
# AT_044     DISENCHANT_GOLDEN   400
# EX1_345t     CRAFTING_NORMAL   400
# EX1_345t     CRAFTING_GOLDEN  1600
# EX1_345t   DISENCHANT_NORMAL   100
# EX1_345t   DISENCHANT_GOLDEN   400
# EX1_009      CRAFTING_NORMAL   100
# EX1_009      CRAFTING_GOLDEN   800
# EX1_009    DISENCHANT_NORMAL    20
# EX1_009    DISENCHANT_GOLDEN   100
# CS2_031      CRAFTING_NORMAL    40
# CS2_031      CRAFTING_GOLDEN   400
# CS2_031    DISENCHANT_NORMAL     5
# CS2_031    DISENCHANT_GOLDEN    50
#
# [4040 rows x 2 columns]

# %%
entourages_df.set_index('card_id')
# Out:
#                              entourage_card_id
# card_id
# KAR_A10_22                          KAR_A10_09
# KAR_A10_22                          KAR_A10_02
# KAR_A10_22                          KAR_A10_08
# KAR_A10_22                          KAR_A10_04
# KAR_A10_22                          KAR_A10_05
# TBST_006                              TBST_003
# TBST_006                              TBST_002
# TBST_006                              TBST_001
# BRMA14_10H                            BRMA14_3
# BRMA14_10H                           BRMA14_5H
# BRMA14_10H                           BRMA14_7H
# BRMA14_10H                           BRMA14_9H
# BRMA09_3                              BRMA09_2
# BRMA09_3                              BRMA09_4
# BRMA09_3                              BRMA09_5
# KARA_06_03hp                        KARA_06_01
# BRMA12_2                              BRMA12_6
# BRMA12_2                              BRMA12_5
# BRMA12_2                              BRMA12_7
# BRMA12_2                              BRMA12_4
# BRMA12_2                              BRMA12_3
# TB_PickYourFate_2nd          TB_PickYourFate_1
# TB_PickYourFate_2nd          TB_PickYourFate_4
# TB_PickYourFate_2nd      TB_PickYourFate_7_2nd
# TB_PickYourFate_2nd          TB_PickYourFate_3
# TB_PickYourFate_2nd      TB_PickYourFate_6_2nd
# TB_PickYourFate_2nd     TB_PickYourFate_11rand
# TB_001                               BRMA14_10
# TB_001                              BRMA14_10H
# TB_001                                BRMA09_4
# ...                                        ...
# LOEA16_16H                           LOEA16_10
# LOEA16_16H                           LOEA16_11
# LOEA16_16H                           LOEA16_14
# LOEA16_16H                           LOEA16_15
# LOEA16_16H                            LOEA16_6
# LOEA16_16H                            LOEA16_7
# LOEA16_16H                            LOEA16_9
# LOEA16_16H                           LOEA16_12
# LOEA16_16H                           LOEA16_13
# LOEA16_16H                            LOEA16_8
# TBUD_1                                 CS1_042
# TBUD_1                                 CS2_171
# BRMA13_3H                             BRMA13_8
# BRMA13_3H                             BRMA13_7
# BRMA13_3H                             BRMA13_6
# BRMA13_3H                             BRMA13_5
# TB_MechWar_CommonCards                 GVG_069
# TB_MechWar_CommonCards                 GVG_079
# TB_MechWar_CommonCards                 GVG_034
# TB_MechWar_CommonCards                 GVG_048
# TB_MechWar_CommonCards                 GVG_049
# TB_MechWar_CommonCards                 GVG_088
# KARA_00_10                             EX1_294
# KARA_00_10                             FP1_018
# KARA_00_10                              AT_002
# KARA_00_10                             EX1_287
# KARA_00_10                              tt_010
# KARA_00_10                             EX1_295
# KARA_00_10                             EX1_289
# KARA_00_10                             EX1_594
#
# [328 rows x 1 columns]

# %%
mechanics_df.set_index('card_id')
# Out:
#                                mechanic
# card_id
# AT_132                        BATTLECRY
# GVG_011a            TAG_ONE_TURN_EFFECT
# EX1_583                       BATTLECRY
# LOE_007t                      EVIL_GLOW
# LOE_007t             ImmuneToSpellpower
# CFM_095                     DEATHRATTLE
# BRM_018                       BATTLECRY
# GVG_030                      CHOOSE_ONE
# GVG_030                           TAUNT
# CS2_227                            AURA
# KAR_062                       BATTLECRY
# CFM_712_t17                  JADE_GOLEM
# BRM_011t            TAG_ONE_TURN_EFFECT
# BRMA10_3H                  AI_MUST_PLAY
# KAR_710m                          TAUNT
# EX1_295o            TAG_ONE_TURN_EFFECT
# OG_158                      DEATHRATTLE
# LOE_110t                        TOPDECK
# LOE_110t             ImmuneToSpellpower
# BRMA13_4H                  AI_MUST_PLAY
# EX1_145o            TAG_ONE_TURN_EFFECT
# LOEA09_2e           TAG_ONE_TURN_EFFECT
# EX1_570e            TAG_ONE_TURN_EFFECT
# GVG_069                       BATTLECRY
# hexfrog                           TAUNT
# OG_145                    DIVINE_SHIELD
# OG_145                            TAUNT
# AT_090                          INSPIRE
# AT_060                           SECRET
# TB_MechWar_Minion1                TAUNT
# ...                                 ...
# EX1_284                       BATTLECRY
# LOE_038                            AURA
# AT_083                          INSPIRE
# TB_CoOpv3_BOSS2e                ENRAGED
# GVG_009                       BATTLECRY
# CFM_338                       BATTLECRY
# GVG_097                       BATTLECRY
# GVG_097                           TAUNT
# CFM_852                       BATTLECRY
# LOE_020                       BATTLECRY
# CFM_781                         STEALTH
# GVG_090                       BATTLECRY
# GVG_120                       BATTLECRY
# EX1_055o            TAG_ONE_TURN_EFFECT
# CFM_321                       BATTLECRY
# EX1_082                       BATTLECRY
# FP1_017                            AURA
# FP1_001                     DEATHRATTLE
# AT_089                          INSPIRE
# CFM_646                     DEATHRATTLE
# AT_084                        BATTLECRY
# OG_044a                          CHARGE
# OG_044a                           TAUNT
# LOEA09_3d                  AI_MUST_PLAY
# BRMA13_4                   AI_MUST_PLAY
# EX1_009                         ENRAGED
# BRMA10_3                   AI_MUST_PLAY
# NAX3_02H                   AI_MUST_PLAY
# AT_083e             TAG_ONE_TURN_EFFECT
# CS2_031                          FREEZE
#
# [1079 rows x 1 columns]

# %%
play_requirements_df.set_index('card_id')
# Out:
#                                 play_requirement  value
# card_id
# KARA_00_07                  REQ_NUM_MINION_SLOTS      1
# PRO_001a                    REQ_NUM_MINION_SLOTS      1
# NAX1_01                     REQ_NUM_MINION_SLOTS      1
# DS1h_292_H1                      REQ_STEADY_SHOT      0
# DS1h_292_H1             REQ_MINION_OR_ENEMY_HERO      0
# KAR_076                       REQ_TARGET_TO_PLAY      0
# AT_024                        REQ_TARGET_TO_PLAY      0
# AT_024                      REQ_TARGET_WITH_RACE     15
# AT_024                         REQ_MINION_TARGET      0
# BRMA06_2                    REQ_NUM_MINION_SLOTS      1
# NAX5_02                REQ_MINIMUM_ENEMY_MINIONS      1
# OG_080c                      REQ_FRIENDLY_TARGET      0
# OG_080c                       REQ_TARGET_TO_PLAY      0
# OG_080c                        REQ_MINION_TARGET      0
# CS2_039                       REQ_TARGET_TO_PLAY      0
# CS2_039                        REQ_MINION_TARGET      0
# TB_KaraPortal_002              REQ_MINION_TARGET      0
# CS2_094                       REQ_TARGET_TO_PLAY      0
# TB_SPT_DPromoHP                REQ_MINION_TARGET      0
# BRMA15_3                    REQ_NUM_MINION_SLOTS      1
# CS2_141                  REQ_TARGET_IF_AVAILABLE      0
# CS2_141                       REQ_NONSELF_TARGET      0
# CS2_063                       REQ_TARGET_TO_PLAY      0
# CS2_063                        REQ_MINION_TARGET      0
# CS2_063                         REQ_ENEMY_TARGET      0
# GVG_055e                     REQ_FRIENDLY_TARGET      0
# TB_006                        REQ_TARGET_TO_PLAY      0
# TB_006                         REQ_MINION_TARGET      0
# CFM_621t21             REQ_MINIMUM_TOTAL_MINIONS      1
# LOEA06_04h                    REQ_TARGET_TO_PLAY      0
# ...                                          ...    ...
# GVG_011                        REQ_MINION_TARGET      0
# CFM_061                       REQ_TARGET_TO_PLAY      0
# AT_132_HUNTER                    REQ_STEADY_SHOT      0
# AT_132_HUNTER           REQ_MINION_OR_ENEMY_HERO      0
# GVG_047                        REQ_MINION_TARGET      0
# GVG_047                         REQ_ENEMY_TARGET      0
# EX1_278                       REQ_TARGET_TO_PLAY      0
# CS2_012                       REQ_TARGET_TO_PLAY      0
# CS2_012                         REQ_ENEMY_TARGET      0
# EX1_578                       REQ_TARGET_TO_PLAY      0
# EX1_578                        REQ_MINION_TARGET      0
# KARA_00_10         REQ_SECRET_CAP_FOR_NON_SECRET      0
# KARA_13_11             REQ_MINIMUM_ENEMY_MINIONS      2
# GVG_120                  REQ_TARGET_IF_AVAILABLE      0
# GVG_120                     REQ_TARGET_WITH_RACE     20
# LOEA02_10a                  REQ_NUM_MINION_SLOTS      1
# CS1_130                       REQ_TARGET_TO_PLAY      0
# AT_025                 REQ_MINIMUM_ENEMY_MINIONS      2
# CS2_061                       REQ_TARGET_TO_PLAY      0
# AT_084                       REQ_FRIENDLY_TARGET      0
# AT_084                   REQ_TARGET_IF_AVAILABLE      0
# AT_084                         REQ_MINION_TARGET      0
# BRMA16_3                     REQ_WEAPON_EQUIPPED      0
# BRMA16_3                      REQ_TARGET_TO_PLAY      0
# BRMA16_3                       REQ_MINION_TARGET      0
# EX1_624                       REQ_TARGET_TO_PLAY      0
# AT_044                        REQ_TARGET_TO_PLAY      0
# AT_044                         REQ_MINION_TARGET      0
# AT_132_SHAMAN               REQ_NUM_MINION_SLOTS      1
# CS2_031                       REQ_TARGET_TO_PLAY      0
#
# [776 rows x 2 columns]

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='images/joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table you are working with, and the right table is the table you want to join to the table you are working with.  You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df,how='inner',axis=1)
cards_with_mechanics_df
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-a12f3f66ad17> in <module>()
# ----> 1 cards_with_mechanics_df = cards_df.join(mechanics_df,how='inner',axis=1)
#       2 cards_with_mechanics_df
#
# NameError: name 'cards_df' is not defined

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# First performed an inner join, which only includes records that are present in both tables.  Although there were 2819 records in the left table, there were only 1079 records that existed in both tables, which are what you see in the resulting dataframe.
#
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = None
left_join_df

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# Every record from `cards_with_mechanics_df`, as well as any records from `play_requirements_df` that have matching index values with a record from the left table.
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = None
outer_join_df

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
